# %%
import pandas as pd
import numpy as np
import json
# Opening JSON file
f = open('data.json',)
  
# returns JSON object as 
# a dictionary
data = json.load(f)

# Closing file
f.close()

# %%
# %load_ext autoreload
# %autoreload 2
import pipeline_entity_quote as pipeline
# Out:
# /Users/oooyyyzzz/opt/anaconda3/lib/python3.8/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)
# [nltk_data] Error loading punkt: <urlopen error [Errno 61] Connection
# [nltk_data]     refused>

# %%
result_dict_entity = {}
result_dict_entity = pipeline.get_training_features_entity_smalltrial()
# Out:
# Current Time = 17:38:02
# Current Time = 01:45:45

# %%
result_df_entity = pd.DataFrame.from_dict(result_dict_entity)
result_df_entity
# Out:
# [nltk_data] Error loading punkt: <urlopen error [Errno 61] Connection
# [nltk_data]     refused>
#                               204f5d99-c9de-4bce-ae2f-5e98085b4930  \
# entity_dict      {'PERSON': ['Dianne Primavera', 'Scott Helker'...
# entity_num                                                      54
# entity_type_num                                                  9
#
#                               0526bd0d-41bb-43fe-bdc9-dabeea9dcfaa  \
# entity_dict      {'PERSON': ['Sherwin Gatchalian'], 'CARDINAL':...
# entity_num                                                      22
# entity_type_num                                                  8
#
#                               33e5aa3f-af33-461d-9e51-16a552e6b985  \
# entity_dict      {'PERSON': ['Juan Ponce Enrile', 'Leila de Lim...
# entity_num                                                      39
# entity_type_num                                                  7
#
# ...

# %%
result_df_entity.to_csv("entity_features.csv")

# %%
result_df_entity_t = result_df_entity.T

# %%
result_df_entity_t.to_csv("entity_features.csv")

# %%
result_df_entity_t
# Out:
#                                                                             entity_dict  \
# 204f5d99-c9de-4bce-ae2f-5e98085b4930  {'PERSON': ['Dianne Primavera', 'Scott Helker'...
# 0526bd0d-41bb-43fe-bdc9-dabeea9dcfaa  {'PERSON': ['Sherwin Gatchalian'], 'CARDINAL':...
# 33e5aa3f-af33-461d-9e51-16a552e6b985  {'PERSON': ['Juan Ponce Enrile', 'Leila de Lim...
# d10f9f69-204a-422d-886d-ff59f787fe22  {'PERSON': ['Ann Wang', 'Fidel Macauyag', 'Ang...
# 88ffc85f-b495-4f59-af53-08a92030f9b7  {'PERSON': ['Juan Ponce Enrile', 'Mike Navallo...
# ...                                                                                 ...
# 8dd1f569-7c3f-43c4-9c26-1543d89e032c  {'PERSON': ['Upendra Raghav', 'Jai Shri Ram', ...
# 7fca5388-231e-4206-a5b2-7d3cd765ba80                              {'GPE': ['Malaysia']}
# f351f646-e3de-4b17-a457-c32741aafda0  {'PERSON': ['La', 'Díaz Ordaz', 'Ingreso Famil...
# f2cb35b3-1f70-471e-8bae-207f157c6cdf  {'PERSON': ['Samar', 'de Diatagon', 'Después d...
# ...
