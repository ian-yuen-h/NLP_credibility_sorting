# %%
# get articles from elastic search

# %%
from elasticsearch import Elasticsearch

# %%
es = Elasticsearch([{'host':'localhost', 'port':9200}], http_auth=('uchicago', '3fMy7Wq90LDWBCMEXt6j'))

# %%
res = es.search(
    index='emm_data', 
    size=5000, 
    body={'query':{'match_all':{}}}, 
    _source=['source', 'link']
)

# %%
res['hits']['hits']
# Out:
# [{'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'rfi-en-9ed24ba66f65f094011834de0e814ecb',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.rfi.fr/en/africa/20210401-gbagbo-acquittal-at-icc-raises-questions-over-much-needed-court-reforms-post-election-violence-cote-d-ivoire-africa',
#    'source': 'rfi'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'privacyinternational-f7406e3252f31ec59cbe94066e6c4ab1',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.privacyinternational.org/news-analysis/4465/new-policing-bill-fails-provide-sufficient-safeguards-around-extraction-victims',
#    'source': 'privacyinternational'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': '4-traders-11f30e5e600b03c1fba3d1da7105b342',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.marketscreener.com/news/latest/Alfasigma-It-s-Vein-Week-from-5th-to-11th-of-April--32861884/',
#    'source': 'marketscreener'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'app-en-c812c07dda6f892a289907778c71ed0c',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.app.com.pk/photos-section/a-rescue-1122-staffer-spraying-disinfectants-being-carried-out-at-gurdwara-bhai-biba-singh-as-precautionary-measures-corona-virus/',
#    'source': 'app'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'timesofindia-ae58fbb905a976a2f9fd4dab9979578a',
#   '_score': 1.0,
#   '_source': {'link': 'https://timesofindia.indiatimes.com/india/first-women-sepoys-system-will-take-time-to-accept-but-nation-will-be-proud-soon/articleshow/81839535.cms',
#    'source': 'indiatimes'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'insighthungary-444-hu-0a95acc4363284ca7188fd6db0566a51',
#   '_score': 1.0,
#   '_source': {'link': 'https://insighthungary.444.hu/2021/04/01/prominent-politicians-stoke-resentment-of-educators-in-announcing-their-prioritization-for-vaccination',
#    'source': '444'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'reuters-in-c91fb173bde791de0e409b3ad35d9a05',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.reuters.com/article/us-brazil-politics-police-analysis/analysis-brazils-bolsonaro-seeks-police-support-before-elections-with-reshuffle-idUSKBN2BO529?il=0',
#    'source': 'reuters'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'newsnow-co-uk-0b6953683d31da8182f4d0f1e31fdb45',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.dailyrecord.co.uk/news/politics/alex-salmond-nicola-sturgeon-drama-23833774',
#    'source': 'dailyrecord'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'explica-89baba69c9a7606199c3d0246d68f2f2',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.explica.co/the-sentimental-ex-partner-speaks-of-accused-of-abusing-a-child-and-then-shooting-him-telemundo-miami-51.html',
#    'source': 'explica'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'express-07bb2f311bfca28a390a3b045ac3e291',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.express.co.uk/sport/football/1417891/Chelsea-transfer-news-Erling-Haaland-Barcelona-talks-Mino-Raiola-father',
#    'source': 'express'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'lynnnews-2ff32757775a59c8d7ba82580d6cc368',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.lynnnews.co.uk/news/i-was-too-scared-to-turn-my-attacker-in-now-i-face-him-as-9193593/',
#    'source': 'lynnnews'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'barrie-12ae345f7e8b41454900bd2d3ee33360',
#   '_score': 1.0,
#   '_source': {'link': 'https://montreal.ctvnews.ca/police-in-laval-looking-for-victims-of-man-charged-with-sexual-assault-1.5371064',
#    'source': 'ctvnews'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'reuters-es-fa74b800e843e503ab4064ac3bd91f39',
#   '_score': 1.0,
#   '_source': {'link': 'https://www

#   '_score': 1.0,
#   '_source': {'link': 'https://www.rfi.fr/en/allies-raise-alarm-over-health-of-hunger-striking-navalny',
#    'source': 'rfi'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'itartass_en-b38ee45365704c48f73fcb1c468d60f1',
#   '_score': 1.0,
#   '_source': {'link': 'https://tass.com/world/1273045', 'source': 'tass'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'armradio-551d5391831adbf3c8973480a87997dd',
#   '_score': 1.0,
#   '_source': {'link': 'https://en.armradio.am/2021/04/01/slovak-parliament-calls-on-government-eu-to-ensure-the-release-of-armenian-pows/',
#    'source': 'armradio'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'dailystar-99f60178c0ce0eff78a9bd047038a663',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.dailystar.co.uk/news/world-news/horror-teen-girls-dragged-forest-23834936',
#    'source': 'dailystar'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'CBSnews-ab38eccc89c4eb92ad9ace1dddae9036',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.cbsnews.com/video/racial-tensions-flare-after-violent-arrest-of-u-va-student-leader/',
#    'source': 'cbsnews'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'dailypost-3f6c25a7ab2b4a1a2a126a6874d66596',
#   '_score': 1.0,
#   '_source': {'link': 'https://dailypost.ng/2021/04/01/ebonyi-enugu-massacre-ipobs-esn-will-avenge-killings-nnamdi-kanu/',
#    'source': 'dailypost'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'azernews-7de97df1a09f35531760d9a3e02c4355',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.azernews.az/nation/177567.html',
#    'source': 'azernews'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'europost-57a76442758d212a899b071be9ccc5f0',
#   '_score': 1.0,
#   '_source': {'link': 'https://europost.eu/en/a/view/berlin-set-to-impose-nighttime-ban-on-gatherings-from-friday-33867',
#    'source': 'europost'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': '4-traders-658fdbbfc79b9498195860b3eb3fc5f4',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.marketscreener.com/news/latest/U-S-Stimulus-Package-Won-t-Have-Much-Impact-on-China-s-Financial-Markets-PBOC-Official-Says--32860927/',
#    'source': 'marketscreener'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': '4-traders-8d049fa8f521dee5dd21e641d9d8e7da',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.marketscreener.com/quote/stock/AIRBUS-SE-4637/news/Airbus-nbsp-We-believe-that-empowering-women-promoting-equal-opportunity-and-ending-all-forms-of-32860722/',
#    'source': 'marketscreener'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'zimeye-73637307a4d15093a2d72197964deb0b',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.zimeye.net/2021/04/01/ed-dancing-on-sand-dunes/',
#    'source': 'zimeye'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'newstatesman-085c69b1aee17455c9202f530fed190a',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.newstatesman.com/politics/staggers/2021/04/why-boris-johnson-s-war-woke-troubles-tory-mps',
#    'source': 'newstatesman'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'msn-uk-b46487cdfcb8af952e14bfe72e59d3b5',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.msn.com/en-gb/news/uknews/met-officer-accused-of-rape-continues-to-serve-while-facing-misconduct-case/ar-BB1fcuPm',
#    'source': 'msn'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'haberler-en-0147566065d512a87fea8ed55904fb23',
#   '_score': 1.0,
#   '_source': {'link': 'https://en.haberler.com/turkish-field-hospital-in-cox-s-bazar-a-beacon-of-1582950/',
#    'source': 'haberler'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'yahoo-sg-e7e92fa2923a1d87fc5714114872d153',
#   '_score': 1.0,
#   '_source': {'link': 'https://sg.news.yahoo.com/north-macedonia-shock-germany-france-213924317.html',
#    'source': 'yahoo'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'worldmaritimenews-a62965ca8c0fc919cd75787e9920a486',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.offshore-energy.biz/intercargo-dry-bulk-sector-hit-the-hardest-by-vaccination-lottery/',
#    'source': 'offshore-energy'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'ahram-EN-833001ec590009cf4997c3f6a66800c5',
#   '_score': 1.0,
#   '_source': {'link': 'https://english.ahram.org.eg/NewsContent/2/9/408309/World/International/Berlin-set-to-impose-nighttime-ban-on-gatherings-f.aspx',
#    'source': 'ahram'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'dailysabah-ebb94a6c6adf523b1ec90655a974353e',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.dailysabah.com/world/europe/strictly-legal-russia-prison-denies-navalny-torture-claims',
#    'source': 'dailysabah'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'theepochtimes-5f3a6bdaca54081f2cf99b5d68e5d60f',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.theepochtimes.com/biden-would-strongly-support-moving-baseballs-all-star-game-out-of-atlanta-over-georgia-election-law_3758446.html',
#    'source': 'theepochtimes'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'cnbc-1674b0820bf7679c75a0dc3ca87ab460',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.cnbc.com/2021/04/01/russia-and-ukraine-tensions-grow-again-on-the-border.html',
#    'source': 'cnbc'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'rtl-BE-9fc04c7d4bb7ed1337081699a343e948',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.rtl.be/info/monde/europe/birmanie-londres-sanctionne-un-conglomerat-lie-a-la-junte-1290300.aspx?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+Rtlinfos-ALaUne+%28RTL.be+-+La+une+de+l%27actualit%C3%A9%29',
#    'source': 'rtl'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'news-24-f3ffb4cb442f0a5f2c5c0e84733de979',
#   '_score': 1.0,
#   '_source': {'link': 'https://news-24.fr/les-progressistes-disent-que-la-politique-etrangere-de-biden-est-la-meme-que-celle-de-trump-ils-ont-tort/',
#    'source': 'news-24'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'news-24-32f80bcaa059a4a80dcca47e5628860e',
#   '_score': 1.0,
#   '_source': {'link': 'https://news-24.fr/lattaque-anti-asiatique-a-new-york-touche-un-nerf-aux-philippines/',
#    'source': 'news-24'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'lesnouvellesnews-7ac404b02db01e1f9b1388c20462247d',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.lesnouvellesnews.fr/incroyables-mariages-gitans-pourquoi-marlene-schiappa-interpelle-le-csa/',
#    'source': 'lesnouvellesnews'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'rfi-fr-60e2257c364db8c754559aff0cfcc586',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.rfi.fr/fr/afrique/20210401-acquittement-de-laurent-gbagbo-devant-la-cpi-un-retour-en-c%C3%B4te-d-ivoire-est-il-possible',
#    'source': 'rfi'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'lamontagne-2912085782e0e5451f266509ac73dcb0',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.lamontagne.fr/moulins-03000/actualites/six-mois-de-detention-sous-surveillance-electronique-pour-agressions-sexuelles-a-moulins-allier_13935483/',
#    'source': 'lamontagne'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'mali-web-96710d641ca4629ea104107be96a2f12',
#   '_score': 1.0,
#   '_source': {'link': 'http://mali-web.org/crise-malienne/crimes-de-guerre-presumes-a-bounti-bientot-une-enquete-de-la-cour-europeenne-des-droits-de-lhomme-sur-larmee-francaise',
#    'source': 'mali-web'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'actu-0c2d787585a43bdcfe2a749879d4d76c',
#   '_score': 1.0,
#   '_source': {'link': 'https://actu.fr/auvergne-rhone-alpes/montferrat_38256/pres-de-grenoble-un-homme-interpelle-pour-avoir-tente-d-etrangler-et-de-violer-une-joggeuse_40722164.html',
#    'source': 'actu'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'rtbf-5e6cdfac1ffe95f561daf1929fe4b1d8',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.rtbf.be/auvio/detail_un-jour-dans-l-histoire?id=2753610',
#    'source': 'rtbf'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'rtbf-edd3c352409bce868bfd1223bf507572',
#   '_score': 1.0,
#   '_source': {'link': 'https://www
}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'timescolonist-66c1dda3e2096e0243800431be0baab1',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.timescolonist.com/police-chief-kneeling-on-floyd-s-neck-violated-policy-1.24303128',
#    'source': 'timescolonist'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'timescolonist-7e4c0f1f140e49fd743a9e51aea8762a',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.timescolonist.com/news/local/online-registration-for-covid-19-vaccine-to-launch-tuesday-in-b-c-1.24303328',
#    'source': 'timescolonist'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'newsbreak-USA-287b6b6205077756248ed7110e993025',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.newsbreak.com/news/2197817189014/derek-chauvin-trial-april-5-live-updates-mpd-chief-medaria-arradondo-says-ex-officer-violated-departmental-policy',
#    'source': 'newsbreak'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'vanguardngr-939a5bfc75716a1208cbe1c7fdbce611',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.vanguardngr.com/2021/04/nscdc-arrests-four-suspects-for-allegedly-raping-woman-to-death/',
#    'source': 'vanguardngr'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'newsnow-co-uk-ef871629a8b1f0a68f686d253884655e',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.rawstory.com/trump-wisconsin-2651371009/',
#    'source': 'rawstory'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'cas-info-1e0383544b48d335b40ce43396bbb1d0',
#   '_score': 1.0,
#   '_source': {'link': 'https://cas-info.ca/2021/04/rdc-leglise-du-reveil-du-congo-se-dit-mobilisee-en-vue-de-la-tenue-des-elections-transparentes-credibles-et-apaisees-en-2023/',
#    'source': 'cas-info'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'rfi-fr-f08013d9bc7a2541befa647b9db9597b',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.rfi.fr/fr/afrique/20210405-scandale-en-alg%C3%A9rie-le-jeune-sa%C3%AFd-chetouane-accuse-des-policiers-de-violences-sexuelles',
#    'source': 'rfi'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'news-24-b8228394c1bedc719cab425c14b65a3e',
#   '_score': 1.0,
#   '_source': {'link': 'https://news-24.fr/les-entreprises-condamnent-la-nouvelle-loi-de-vote-restrictive-de-la-georgie-leur-critique-est-venue-trop-tard/',
#    'source': 'news-24'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'haaretz-41cfbc12112e6d5363bcec3712a5519b',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.haaretz.com/middle-east-news/meet-the-hashemites-who-are-the-key-players-in-jordan-s-palace-intrigue-1.9681117',
#    'source': 'haaretz'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'euro-burma-101f05af79dd32cea9c9a834e5fc8c40',
#   '_score': 1.0,
#   '_source': {'link': 'http://www.euro-burma.eu/news/show/47039/',
#    'source': 'euro-burma'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'TheFrontierPost-en-ba9c0986758ea8af25d91f258e85642c',
#   '_score': 1.0,
#   '_source': {'link': 'https://thefrontierpost.com/cold-war-mentality-wont-restore-us-declining-soft-power/',
#    'source': 'thefrontierpost'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'island-ceeb97b996afcb66476d1fe9be4f74ac',
#   '_score': 1.0,
#   '_source': {'link': 'https://island.lk/ragging-rages-on-from-centres-to-margins/',
#    'source': 'island'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'urdupoint-f83510309ddba94b971c891f9a520116',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.urdupoint.com/en/pakistan/efforts-being-made-for-vaccination-of-1100-pr-1213268.html',
#    'source': 'urdupoint'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'nj-8e17f213d29ca787a339f3c059d42967',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.nj.com/staff/ahoover/posts.html',
#    'source': 'nj'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'urdupoint-8f1d804961dfab547f1682be4192ecfe',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.urdupoint.com/en/world/pope-francis-in-easter-message-calls-for-end-1213382.html',
#    'source': 'urdupoint'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 
}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'moderndiplomacy-f89c4cb6a8d18792eed603c88e62b00f',
#   '_score': 1.0,
#   '_source': {'link': 'https://moderndiplomacy.eu/2021/04/01/plastic-pollution-disproportionately-hitting-marginalized-groups/',
#    'source': 'moderndiplomacy'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'thechronicleherald-63d127cd229be2b71038393758c10424',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.thechronicleherald.ca/news/canada/another-top-military-officer-steps-aside-amid-allegations-of-sexual-assault-570932/',
#    'source': 'thechronicleherald'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'en-finance-yahoo-cc432d0f7b7a31da29b8459a1a649ce2',
#   '_score': 1.0,
#   '_source': {'link': 'https://finance.yahoo.com/news/biden-singles-amazon-not-paying-230925764.html',
#    'source': 'yahoo'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'straitstimesSG-a54c8fa8728ed581bf79d93fbdddb5f6',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.straitstimes.com/asia/east-asia/hong-kong-police-warn-residents-to-avoid-red-lines-on-politics',
#    'source': 'straitstimes'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'reliefWeb-6444837944d60e98852e48d058e34098',
#   '_score': 1.0,
#   '_source': {'link': 'https://reliefweb.int/report/myanmar/myanmar-significant-action-needed-security-council-prevent-bloodbath',
#    'source': 'reliefweb'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'reliefWeb-d560dc5538a05c7d4f31286e4116c997',
#   '_score': 1.0,
#   '_source': {'link': 'https://reliefweb.int/report/cameroon/cameroon-price-bulletin-march-2021',
#    'source': 'reliefweb'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'reliefWeb-e0bc99db52de25042c6df54b1b2c4e11',
#   '_score': 1.0,
#   '_source': {'link': 'https://reliefweb.int/report/ethiopia/ethiopia-tigray-conflict-fact-sheet-5-fiscal-year-fy-2021',
#    'source': 'reliefweb'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'loopjamaica-40e1f2d49442933bbe8e4112e526c0bf',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.loopjamaica.com/content/st-james-cops-list-persons-wanted-major-offences-parish',
#    'source': 'loopjamaica'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'dailymail-249e4333cf57298b2abb59c4f031db5e',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.dailymail.co.uk/news/article-9424657/Moment-Mexican-smugglers-drop-two-toddlers-14-foot-high-border-barrier.html?ns_mchannel=rss&ns_campaign=1490&ito=1490',
#    'source': 'dailymail'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'tribuneonlineng-48a6ac4560181f9dad6ad5fccf77c8a7',
#   '_score': 1.0,
#   '_source': {'link': 'https://tribuneonlineng.com/on-efcc-chairmans-commitment-to-corruption-fight/',
#    'source': 'tribuneonlineng'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'al-monitor-87d5d9e06cad7fcb7a8fa4ff64065a43',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.al-monitor.com/originals/2021/03/takeaway-china-moves-elevate-its-role-middle-east-faces-odds',
#    'source': 'al-monitor'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'CBSnews-2cffebc5d4b07dcbaabd387dddd4530d',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.cbsnews.com/video/disinformation-warfare-predicting-murder-impact/',
#    'source': 'cbsnews'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'eurasiareview-e39f882d640ae68f6d4e3b2fa7477172',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.eurasiareview.com/01042021-the-us-war-on-drugs-is-driving-the-displacement-crisis-oped/',
#    'source': 'eurasiareview'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'eurasiareview-4df7433147bcdcfa4c083b579e6c82a4',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.eurasiareview.com/01042021-dominican-wall-of-anti-haitianism-keeps-neocolonial-inequity-alive-oped/',
#    'source': 'eurasiareview'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'eurasiareview-c36cc59a32210a63797c2b2057bb4d1c',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.eurasiareview.com/01042021-malaysias-rubber-glove-industry-the-good-the-bad-and-the-ugly-analysis/',
#    'source': 'eurasiareview'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 
}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'mongabay-1706760e79c27cb30e4cef28b5e11b89',
#   '_score': 1.0,
#   '_source': {'link': 'https://news.mongabay.com/2021/04/what-other-country-would-do-this-to-its-people-cambodian-land-grab-victims-seek-intl-justice/',
#    'source': 'mongabay'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'eurasiareview-aee7807d008b18202e9d499815ce5e81',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.eurasiareview.com/01042021-february-money-supply-growth-hit-yet-another-all-time-high-oped/',
#    'source': 'eurasiareview'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'eurasiareview-165c971c9c6e9d4a8fc2ee37d3f82330',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.eurasiareview.com/01042021-poland-escalating-threats-to-women-activists/',
#    'source': 'eurasiareview'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'independent-ie-d777dd8685c092f8c4d16d9fe2d40ad6',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.independent.ie/world-news/navalny-goes-on-hungerstrike-over-lack-of-medical-treatment-40263730.html',
#    'source': 'independent'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'sunnewsonline-b222c76ca91d06d63444cf742e6ad67f',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.sunnewsonline.com/3-killed-commercial-activities-paralysed-as-2-edo-communities/',
#    'source': 'sunnewsonline'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'sunnewsonline-7fe898c846fa12e12c8d0d9a09eea7db',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.sunnewsonline.com/ebonyi-massacre-umahi-imposes-curfew/',
#    'source': 'sunnewsonline'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'mercurynews-f73b5683b03249233c74b6df60b5b6ac',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.mercurynews.com/2021/03/31/7942215/',
#    'source': 'mercurynews'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'BangkokPost-de55259696e6ff41674eb3f015132713',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.bangkokpost.com/opinion/opinion/2093015/no-safety-net-for-reporters-in-post-coup-myanmar',
#    'source': 'bangkokpost'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'financialpost-ad611b94e5e3bda8216376aaac0f6573',
#   '_score': 1.0,
#   '_source': {'link': 'https://financialpost.com/pmn/business-pmn/delta-coca-cola-blast-home-state-georgias-voting-restrictions-as-unacceptable-2',
#    'source': 'financialpost'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'eurweb-e2203921a094274055b541ff23d53ddd',
#   '_score': 1.0,
#   '_source': {'link': 'https://eurweb.com/2021/03/31/boy-7-charged-with-rape-in-new-york-atty-calls-it-absurd/',
#    'source': 'eurweb'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'thenews-pk-6467fd7a3d2183dcb10b48835e62fc30',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.thenews.com.pk/print/812894-thai-activists-charged-for-violence-against-the-queen',
#    'source': 'thenews'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'thenews-pk-57cbe1735e4cd63d8c7ff85fc2a26209',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.thenews.com.pk/print/812893-eu-ministers-vow-syria-war-criminals-won-t-go-unpunished',
#    'source': 'thenews'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'thenews-pk-d956eba17bbccb99a173b56358e74f28',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.thenews.com.pk/print/812889-battle-royale-in-west-bengal-amid-crucial-state-poll',
#    'source': 'thenews'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'thenews-pk-12ce1a9d7c0eb208a347e366a518d6a0',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.thenews.com.pk/print/812887-turning-page-on-donald-trump-us-vows-to-defend-rights-everywhere',
#    'source': 'thenews'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'thenews-pk-e888bb8db938108d4aa7d6149c0d7888',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.thenews.com.pk/print/812909-case-study-of-victims-survivors-of-violence-launched',
#    'source': 'thenews'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'thenews-pk-19fd3041375724074f9bf69d8fa245a3',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.thenews.com.pk/print/812902-627-cases-registered-over-sops-breach',
#    'source': 'thenews'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'thenews-pk-a151d61872cf9475ac43c1c21a5b3507',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.thenews.com.pk/print/812876-families-of-shia-missing-persons-to-start-sit-in-at-numaish-chowrangi-tomorrow',
#    'source': 'thenews'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'thenews-pk-24af43880d5b60680d678e8d10332633',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.thenews.com.pk/print/812870-karachi-university-s-visiting-teachers-not-paid-for-over-seven-months',
#    'source': 'thenews'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'thenews-pk-8e737c2d2347918b9adf792611bd581e',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.thenews.com.pk/print/812866-tribunal-restrains-anti-encroachment-teams-from-demolishing-leased-houses',
#    'source': 'thenews'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'newsnow-co-uk-340ab7b7cf3abde899b58115e4d8e7fa',
#   '_score': 1.0,
#   '_source': {'link': 'https://nymag.com/intelligencer/2021/03/biden-infrastructure-plan-analysis.html',
#    'source': 'nymag'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'newsnow-co-uk-f5637805600c7b31e21c04177bf4a1c2',
#   '_score': 1.0,
#   '_source': {'link': 'https://www.wsws.org/en/articles/2021/04/01/tulu-a01.html',
#    'source': 'wsws'}},
#  {'_index': 'emm_data',
#   '_type': '_doc',
#   '_id': 'yalibnan-7ed68a5feedaec472b62db73a2c07c1c',
#   '_score': 1.0,
#   '_source': {'link': 'https://yalibnan.com/2021/04/01/u-s-human-rights-report-documents-chinas-genocide-in-xinjiang/',
#    'source': 'yalibnan'}},
#  ...]

# %%
import json

# store article's id and url in json
def get_id_and_url(res):
    results = res['hits']['hits']
    res_dict = {}
    for r in results:
        # get result id and url
        res_id = r['_id']
        res_url = r['_source']['link']
        
        # store the values in a dictionary
        res_dict[res_id] = res_url    
#     j = json.dumps(res_dict)
    # save info to a json file
    with open('data.json', 'w') as f:
        json.dump(res_dict, f)

get_id_and_url(res)

# %%
# get and return a list of urls
def get_urls():
    results = res['hits']['hits']
    urls = []
    for u in results:
        url = u['_source']['link']
        urls.append(url)
    return urls
    
len(get_urls())
# Out:
# 5000

# %%
# Extracting information from the article

# %%
import newspaper
from newspaper import Article

# %%
# get article's url
url = res['hits']['hits'][0].get('_source')['link']

# create Article object
article = Article(url)

# download & parse the article
article.download()
article.parse()

# extract NL properties from the text
article.nlp()

# %%
# get author(s), publish date & top image
f'author: {article.authors},    publication date: {article.publish_date},    top image: {article.top_image}'
# Out:
# "author: ['Daniel Finnan'],    publication date: 2021-04-01 00:00:00,    top image: https://s.rfi.fr/media/display/377fe31c-92c4-11eb-875f-005056bf87d6/w:1280/p:16x9/000_1OQ9T4.jpg"

# %%
# get the article's text
article.text
# Out:
# 'Laurent Gbagbo at the courtroom during a hearing on his request for unconditional release in The Hague on 2 February 2020.\n\nJudges at the International Criminal Court (ICC) on Thursday dismissed an appeal against Côte d’Ivoire’s former President Laurent Gbagbo, confirming his acquittal for crimes against humanity and paving the way for his return to the West African country after almost a decade.The decision was a blow for victims\' families and provoked concern among observers who say the case highlights the need for serious reform within the court system.\n\nAdvertising Read more\n\n“This is a victory for a man, President Gbagbo, whose innocence is finally fully recognised,” said Gbagbo’s lawyer Emmanuel Altit. “President Gbagbo always said that he believed in justice. Today, justice has been done.”\n\nGbagbo and his right-hand man Charles Blé Goudé were found not guilty of crimes against humanity in 2019 related to post-election violence in Côte d’Ivoire more than 10 years ago. Some 3,000 people were killed following disputed results in the 2010 polls.\n\nGbagbo refused to cede power to incumbent President Alassane Ouattara, but with the help of a French military intervention he was removed from the presidency. He was sent to the world court the next year.\n\nICC prosecutor Fatou Bensouda appealed the 15 January 2019 decision, arguing that the court “committed legal and procedural errors”, highlighting that judges did not make a proper written judgement until six months after an oral acquittal.\n\nBensouda had said Gbagbo and Blé Goudé’s acquittal must be reversed and must be declared a mistrial, saying the judges did not apply a “clearly defined standard of proof” in reviewing the evidence.\n\n“I’m not surprised, the trial judgement had been quite clear and conclusive on the fact that the prosecutor had not presented enough evidence or evidence that was convincing enough,” said Mariana Pena, who has been following the trial for the Open Society Justice Initiative, a non-governmental organisation.\n\nMore than 4,600 documents were examined and 96 witnesses appeared on the stand during the trial of the first former head of state to sit in the dock at The Hague court.\n\nPart of the prosecution’s appeal relied on an argument about a claimed procedural error when the original verdict was handed down in 2019, with the prosecutors office saying judges did not make a proper written judgement.\n\n“I think the reason the prosecution appealed on those procedural grounds is because that they’re seeking to establish jurisprudence for the way forward,” legal expert Pena told RFI, explaining that this was probably a move by Bensouda to try and establish a standard for how judgments are delivered.\n\nICC reforms\n\nAnother key tenet of the prosecutors appeal was how the judges set standards for the evidence against Gbagbo and youth wing leader Blé Goudé.\n\nThe appeal verdict served to further underline the need for reforms to the ICC, a process that has already started since the original verdict, according to Pena, who has previously represented victims at the ICC.\n\n“The damage of the acquittal has been done,” she said, describing how the 2019 verdict, in part, encouraged many stakeholders to push for change, especially on questions about the prosecutor providing sufficient evidence.\n\n“Things need to change in terms of how investigations are conducted,” Pena added, outlining specific criticism about how in-country investigation teams operate, an aspect already identified in the review process.\n\nSome criticism has been levelled at ICC Prosecutor Bensouda herself, who will soon be replaced by incoming prosecutor Karim Khan, a British barrister.\n\nNevertheless, Pena points to some successes achieved by the Gambian lawyer, such as the conviction of Congolese warlord Bosco Ntaganda, who’s conviction was confirmed earlier this week.\n\n“I think it’s not just about the person who leads,” said the Argentine lawyer, referring to a resi ...

# %%
# now perform NLP on the article's text with spaCy

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
# store the article's text
article_text = article.text

# tokenize the text
article_doc = nlp(article_text)

# %%
# extract tokens from the doc
article_tokens = [token.text for token in article_doc]

# print the tokens
article_tokens
# Out:
# ['Laurent',
#  'Gbagbo',
#  'at',
#  'the',
#  'courtroom',
#  'during',
#  'a',
#  'hearing',
#  'on',
#  'his',
#  'request',
#  'for',
#  'unconditional',
#  'release',
#  'in',
#  'The',
#  'Hague',
#  'on',
#  '2',
#  'February',
#  '2020',
#  '.',
#  '\n\n',
#  'Judges',
#  'at',
#  'the',
#  'International',
#  'Criminal',
#  'Court',
#  '(',
#  'ICC',
#  ')',
#  'on',
#  'Thursday',
#  'dismissed',
#  'an',
#  'appeal',
#  'against',
#  'Côte',
#  'd’Ivoire',
#  '’s',
#  'former',
#  'President',
#  'Laurent',
#  'Gbagbo',
#  ',',
#  'confirming',
#  'his',
#  'acquittal',
#  'for',
#  'crimes',
#  'against',
#  'humanity',
#  'and',
#  'paving',
#  'the',
#  'way',
#  'for',
#  'his',
#  'return',
#  'to',
#  'the',
#  'West',
#  'African',
#  'country',
#  'after',
#  'almost',
#  'a',
#  'decade',
#  '.',
#  'The',
#  'decision',
#  'was',
#  'a',
#  'blow',
#  'for',
#  'victims',
#  "'",
#  'families',
#  'and',
#  'provoked',
#  'concern',
#  'among',
#  'observers',
#  'who',
#  'say',
#  'the',
#  'case',
#  'highlights',
#  'the',
#  'need',
#  'for',
#  'serious',
#  'reform',
#  'within',
#  'the',
#  'court',
#  'system',
#  '.',
#  '\n\n',
#  'Advertising',
#  'Read',
#  'more',
#  '\n\n',
#  '“',
#  'This',
#  'is',
#  'a',
#  'victory',
#  'for',
#  'a',
#  'man',
#  ',',
#  'President',
#  'Gbagbo',
#  ',',
#  'whose',
#  'innocence',
#  'is',
#  'finally',
#  'fully',
#  'recognised',
#  ',',
#  '”',
#  'said',
#  'Gbagbo',
#  '’s',
#  'lawyer',
#  'Emmanuel',
#  'Altit',
#  '.',
#  '“',
#  'President',
#  'Gbagbo',
#  'always',
#  'said',
#  'that',
#  'he',
#  'believed',
#  'in',
#  'justice',
#  '.',
#  'Today',
#  ',',
#  'justice',
#  'has',
#  'been',
#  'done',
#  '.',
#  '”',
#  '\n\n',
#  'Gbagbo',
#  'and',
#  'his',
#  'right',
#  '-',
#  'hand',
#  'man',
#  'Charles',
#  'Blé',
#  'Goudé',
#  'were',
#  'found',
#  'not',
#  'guilty',
#  'of',
#  'crimes',
#  'against',
#  'humanity',
#  'in',
#  '2019',
#  'related',
#  'to',
#  'post',
#  '-',
#  'election',
#  'violence',
#  'in',
#  'Côte',
#  'd’Ivoire',
#  'more',
#  'than',
#  '10',
#  'years',
#  'ago',
#  '.',
#  'Some',
#  '3,000',
#  'people',
#  'were',
#  'killed',
#  'following',
#  'disputed',
#  'results',
#  'in',
#  'the',
#  '2010',
#  'polls',
#  '.',
#  '\n\n',
#  'Gbagbo',
#  'refused',
#  'to',
#  'cede',
#  'power',
#  'to',
#  'incumbent',
#  'President',
#  'Alassane',
#  'Ouattara',
#  ',',
#  'but',
#  'with',
#  'the',
#  'help',
#  'of',
#  'a',
#  'French',
#  'military',
#  'intervention',
#  'he',
#  'was',
#  'removed',
#  'from',
#  'the',
#  'presidency',
#  '.',
#  'He',
#  'was',
#  'sent',
#  'to',
#  'the',
#  'world',
#  'court',
#  'the',
#  'next',
#  'year',
#  '.',
#  '\n\n',
#  'ICC',
#  'prosecutor',
#  'Fatou',
#  'Bensouda',
#  'appealed',
#  'the',
#  '15',
#  'January',
#  '2019',
#  'decision',
#  ',',
#  'arguing',
#  'that',
#  'the',
#  'court',
#  '“',
#  'committed',
#  'legal',
#  'and',
#  'procedural',
#  'errors',
#  '”',
#  ',',
#  'highlighting',
#  'that',
#  'judges',
#  'did',
#  'not',
#  'make',
#  'a',
#  'proper',
#  'written',
#  'judgement',
#  'until',
#  'six',
#  'months',
#  'after',
#  'an',
#  'oral',
#  'acquittal',
#  '.',
#  '\n\n',
#  'Bensouda',
#  'had',
#  'said',
#  'Gbagbo',
#  'and',
#  'Blé',
#  'Goudé',
#  '’s',
#  'acquittal',
#  'must',
#  'be',
#  'reversed',
#  'and',
#  'must',
#  'be',
#  'declared',
#  'a',
#  'mistrial',
#  ',',
#  'saying',
#  'the',
#  'judges',
#  'did',
#  'not',
#  'apply',
#  'a',
#  '“',
#  'clearly',
#  'defined',
#  'standard',
#  'of',
#  'proof',
#  '”',
#  'in',
#  'reviewing',
#  'the',
#  'evidence',
#  '.',
#  '\n\n',
#  '“',
#  'I',
#  '’m',
#  'not',
#  'surprised',
#  ',',
#  'the',
#  'trial',
#  'judgement',
#  'had',
#  'been',
#  'quite',
#  'clear',
#  'and',
#  'conclusive',
#  'on',
#  'the',
#  'fact',
#  'that',
#  'the',
#  'prosecutor',
#  'had',
#  'not',
#  'presented',
#  'enough',
#  'evidence',
#  'or',
#  'evidence',
#  'that',
#  'was',
#  'convincing',
#  'enough',
#  ',',
#  '”',
#  'said',
#  'Mariana',
#  'Pena',
#  ',',
#  'who',
#  'has',
#  'been',
#  'following',
#  'the',
#  'trial',
#  'for',
#  'the',
#  'Open',
#  'Society',
#  'Justice',
#  'Initiative',
#  ',',
#  'a',
#  'non',
#  '-',
#  'governmental',
#  'organisation',
#  '.',
#  '\n\n',
#  'More',
#  'than',
#  '4,600',
#  'documents',
#  'were',
#  'examined',
#  'and',
#  '96',
#  'witnesses',
#  'appeared',
#  'on',
#  'the',
#  'stand',
#  'during',
#  'the',
#  'trial',
#  'of',
#  'the',
#  'first',
#  'former',
#  'head',
#  'of',
#  'state',
#  'to',
#  'sit',
#  'in',
#  'the',
#  'dock',
#  'at',
#  'The',
#  'Hague',
#  'court',
#  '.',
#  '\n\n',
#  'Part',
#  'of',
#  'the',
#  'prosecution',
#  '’s',
#  'appeal',
#  'relied',
#  'on',
#  'an',
#  'argument',
#  'about',
#  'a',
#  'claimed',
#  'procedural',
#  'error',
#  'when',
#  'the',
#  'original',
#  'verdict',
#  'was',
#  'handed',
#  'down',
#  'in',
#  '2019',
#  ',',
#  'with',
#  'the',
#  'prosecutors',
#  'office',
#  'saying',
#  'judges',
#  'did',
#  'not',
#  'make',
#  'a',
#  'proper',
#  'written',
#  'judgement',
#  '.',
#  '\n\n',
#  '“',
#  'I',
#  'think',
#  'the',
#  'reason',
#  'the',
#  'prosecution',
#  'appealed',
#  'on',
#  'those',
#  'procedural',
#  'grounds',
#  'is',
#  'because',
#  'that',
#  'they',
#  '’re',
#  'seeking',
#  'to',
#  'establish',
#  'jurisprudence',
#  'for',
#  'the',
#  'way',
#  'forward',
#  ',',
#  '”',
#  'legal',
#  'expert',
#  'Pena',
#  'told',
#  'RFI',
#  ',',
#  'explaining',
#  'that',
#  'this',
#  'was',
#  'probably',
#  'a',
#  'move',
#  'by',
#  'Bensouda',
#  'to',
#  'try',
#  'and',
#  'establish',
#  'a',
#  'standard',
#  'for',
#  'how',
#  'judgments',
#  'are',
#  'delivered',
#  '.',
#  '\n\n',
#  'ICC',
#  'reforms',
#  '\n\n',
#  'Another',
#  'key',
#  'tenet',
#  'of',
#  'the',
#  'prosecutors',
#  'appeal',
#  'was',
#  'how',
#  'the',
#  'judges',
#  'set',
#  'standards',
#  'for',
#  'the',
#  'evidence',
#  'against',
#  'Gbagbo',
#  'and',
#  'youth',
#  'wing',
#  'leader',
#  'Blé',
#  'Goudé',
#  '.',
#  '\n\n',
#  'The',
#  'appeal',
#  'verdict',
#  'served',
#  'to',
#  'further',
#  'underline',
#  'the',
#  'need',
#  'for',
#  'reforms',
#  'to',
#  'the',
#  'ICC',
#  ',',
#  'a',
#  'process',
#  'that',
#  'has',
#  'already',
#  'started',
#  'since',
#  'the',
#  'original',
#  'verdict',
#  ',',
#  'according',
#  'to',
#  'Pena',
#  ',',
#  'who',
#  'has',
#  'previously',
#  'represented',
#  'victims',
#  'at',
#  'the',
#  'ICC',
#  '.',
#  '\n\n',
#  '“',
#  'The',
#  'damage',
#  'of',
#  'the',
#  'acquittal',
#  'has',
#  'been',
#  'done',
#  ',',
#  '”',
#  'she',
#  'said',
#  ',',
#  'describing',
#  'how',
#  'the',
#  '2019',
#  'verdict',
#  ',',
#  'in',
#  'part',
#  ',',
#  'encouraged',
#  'many',
#  'stakeholders',
#  'to',
#  'push',
#  'for',
#  'change',
#  ',',
#  'especially',
#  'on',
#  'questions',
#  'about',
#  'the',
#  'prosecutor',
#  'providing',
#  'sufficient',
#  'evidence',
#  '.',
#  '\n\n',
#  '“',
#  'Things',
#  'need',
#  'to',
#  'change',
#  'in',
#  'terms',
#  'of',
#  'how',
#  'investigations',
#  'are',
#  'conducted',
#  ',',
#  '”',
#  'Pena',
#  'added',
#  ',',
#  'outlining',
#  'specific',
#  'criticism',
#  'about',
#  'how',
#  'in',
#  '-',
#  'country',
#  'investigation',
#  'teams',
#  'operate',
#  ',',
#  'an',
#  'aspect',
#  'already',
#  'identified',
#  'in',
#  'the',
#  'review',
#  'process',
#  '.',
#  '\n\n',
#  'Some',
#  'criticism',
#  'has',
#  'been',
#  'levelled',
#  'at',
#  'ICC',
#  'Prosecutor',
#  'Bensouda',
#  'herself',
#  ',',
#  'who',
#  'will',
#  'soon',
#  'be',
#  'replaced',
#  'by',
#  'incoming',
#  'prosecutor',
#  'Karim',
#  'Khan',
#  ',',
#  'a',
#  'British',
#  'barrister',
#  '.',
#  '\n\n',
#  'Nevertheless',
#  ',',
#  'Pena',
#  'points',
#  'to',
#  'some',
#  'successes',
#  'achieved',
#  'by',
#  'the',
#  'Gambian',
#  'lawyer',
#  ',',
#  'such',
#  'as',
#  'the',
#  'conviction',
#  'of',
#  'Congolese',
#  'warlord',
#  'Bosco',
#  'Ntaganda',
#  ',',
#  'who',
#  '’s',
#  'conviction',
#  'was',
#  'confirmed',
#  'earlier',
#  'this',
#  'week',
#  '.',
#  '\n\n',
#  '“',
#  'I',
#  'think',
#  'it',
#  '’s',
#  'not',
#  'just',
#  'about',
#  'the',
#  'person',
#  'who',
#  'leads',
#  ',',
#  '”',
#  'said',
#  'the',
#  'Argentine',
#  'lawyer',
#  ',',
#  'referring',
#  'to',
#  'a',
#  'resistance',
#  'to',
#  'change',
#  'within',
#  'the',
#  'ICC',
#  'that',
#  'also',
#  'comes',
#  'from',
#  'other',
#  'senior',
#  'management',
#  'and',
#  'staff',
#  '.',
#  '\n\n',
#  'Search',
#  'for',
#  'justice',
#  '\n\n',
#  'The',
#  'need',
#  'for',
#  'change',
#  'at',
#  'the',
#  'ICC',
#  'will',
#  'not',
#  'be',
#  'much',
#  'comfort',
#  'to',
#  'the',
#  'families',
#  'of',
#  'the',
#  'victims',
#  ',',
#  'as',
#  'the',
#  'confirmation',
#  'of',
#  'Gbagbo',
#  'and',
#  'Blé',
#  'Goudé',
#  '’s',
#  'acquittal',
#  'means',
#  'they',
#  'are',
#  'still',
#  'seeking',
#  'justice',
#  '.',
#  '\n\n',
#  '“',
#  'The',
#  'court',
#  'has',
#  'held',
#  'no',
#  'one',
#  'responsible',
#  'for',
#  'atrocity',
#  'crimes',
#  'committed',
#  'during',
#  'this',
#  'period',
#  ',',
#  '”',
#  'said',
#  'Michele',
#  'Eken',
#  ',',
#  'a',
#  'researcher',
#  'for',
#  'Amnesty',
#  'International',
#  ',',
#  'a',
#  'human',
#  'rights',
#  'organisation',
#  '.',
#  '\n\n',
#  'Eken',
#  'referred',
#  'to',
#  'an',
#  'amnesty',
#  'granted',
#  'by',
#  'President',
#  'Ouattara',
#  'in',
#  '2018',
#  'to',
#  'some',
#  '800',
#  'people',
#  'preventing',
#  'national',
#  'tribunals',
#  'from',
#  'prosecuting',
#  'crimes',
#  'under',
#  'international',
#  'law',
#  '.',
#  '\n\n',
#  '“',
#  'Whether',
#  'at',
#  'the',
#  'national',
#  'or',
#  'international',
#  'level',
#  ',',
#  'victims',
#  'of',
#  'the',
#  '2010',
#  '-',
#  '2011',
#  'violence',
#  'are',
#  'yet',
#  'to',
#  'see',
#  'justice',
#  'and',
#  'reparations',
#  'for',
#  'the',
#  'harm',
#  'they',
#  'suffered',
#  ',',
#  '”',
#  'Amnesty',
#  '’s',
#  'Eken',
#  'said',
#  'in',
#  'a',
#  'statement',
#  '.',
#  '\n\n',
#  'The',
#  'appeals',
#  'verdict',
#  'also',
#  'removes',
#  'one',
#  'of',
#  'the',
#  'last',
#  'obstacles',
#  'preventing',
#  'Gbagbo',
#  '’s',
#  'return',
#  'to',
#  'Côte',
#  'd’Ivoire',
#  '.',
#  'The',
#  'former',
#  'president',
#  'has',
#  'been',
#  'quite',
#  'clear',
#  'in',
#  'expressing',
#  'his',
#  'desire',
#  'to',
#  'return',
#  'home',
#  '.',
#  '\n\n',
#  'But',
#  'the',
#  '75',
#  '-',
#  'year',
#  '-',
#  'old',
#  'remains',
#  'a',
#  'symbol',
#  'of',
#  'the',
#  'polarised',
#  'nature',
#  'of',
#  'Ivorian',
#  'politics',
#  ',',
#  'split',
#  'between',
#  'two',
#  'camps',
#  'with',
#  'divisions',
#  'that',
#  'were',
#  'laid',
#  'bare',
#  'during',
#  'the',
#  'civil',
#  'war',
#  'that',
#  'broke',
#  'out',
#  'in',
#  '2002',
#  'and',
#  'later',
#  'during',
#  'the',
#  'electoral',
#  'crisis',
#  'in',
#  'October',
#  '2010',
#  'when',
#  'Gbagbo',
#  'refused',
#  'to',
#  'step',
#  'down',
#  '.',
#  '\n\n',
#  'Gbagbo',
#  '’s',
#  'return',
#  '\n\n',
#  'Incumbent',
#  'Ouattara',
#  ',',
#  'who',
#  'was',
#  'recently',
#  're',
#  '-',
#  'elected',
#  'for',
#  'a',
#  'third',
#  'term',
#  ...]

# %%
# extract info and perfom NLP on articles
def extract_article_info():
    for url in get_urls()[:5]:
        # create Article object
        article = Article(url)
        
        # check for valid url
        if article.is_valid_url():
            # download and parse the article
            article.download()
            article.parse()
            # extract NL properties from article's text
            article.nlp()
            # print article's text
            print(article.text)
            print('-' * 200)

extract_article_info()

# %%
import spacy
from spacytextblob.spacytextblob import SpacyTestBlob
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-bc273fe77330> in <module>
#       1 import spacy
# ----> 2 from spacytextblob.spacytextblob import SpacyTestBlob
#       3 import numpy as np
#
# ImportError: cannot import name 'SpacyTestBlob' from 'spacytextblob.spacytextblob' (/home/mahdan/uchicago/venv/lib/python3.8/site-packages/spacytextblob/spacytextblob.py)

# %%
nlp = spacy.load('en_core_web_sm')
nlp.add_pipe('spacytextblob')

dict_articles = {}

for each in articles:
    doc = nlp(each)
    dict_articles["id"] = [doc._.polarity, doc._.subjectivity, doc._.assessments]

#subjectivity: 0.0 = objective, 1.0 = subjective
#polarity: measures level of approval/disapproval
#assessments = list of polarity, subjectivity scores for assessed tokens


#x-y plot of subjectivity, polarity
#see if there is any relationship, clustering

import matplotlib.pyplot as plt

def do_plot(subjectivity_vals, polarity_vals, tags):
    # Plot
    plt.plot(subjectivtity_vals, polarity_vals, label="oridinal data")
    plt.xlabel("Subjectivity")
    plt.ylabel("Polarity")
    plt.title("Subjectivity-Polarity Word-level")
    plt.legend()
    m, b = np.polyfit(x, y, 1) #regression
    slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(x, y)
    plt.plot(x, m*x + b)
    plt.savefig("initial_plot.png")
    plt.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-77b69b1e1a08> in <module>
#       1 nlp = spacy.load('en_core_web_sm')
# ----> 2 nlp.add_pipe('spacytextblob')
#       3
#       4 dict_articles = {}
#       5
#
# ~/uchicago/venv/lib/python3.8/site-packages/spacy/language.py in add_pipe(self, factory_name, name, before, after, first, last, source, config, raw_config, validate)
#     771                     lang_code=self.lang,
#     772                 )
# --> 773             pipe_component = self.create_pipe(
#     774                 factory_name,
#     775                 name=name,
#
# ~/uchicago/venv/lib/python3.8/site-packages/spacy/language.py in create_pipe(self, factory_name, name, config, raw_config, validate)
#     637                 lang_code=self.lang,
#     638             )
# --> 639             raise ValueError(err)
#     640         pipe_meta = self.get_factory_meta(factory_name)
#     641         config = config or {}
#
# ValueError: [E002] Can't find factory for 'spacytextblob' for language English (en). This usually happens when spaCy calls `nlp.create_pipe` with a custom component name that's not registered on the current language class. If you're using a Transformer, make sure to install 'spacy-transformers'. If you're using a custom component, make sure you've added the decorator `@Language.component` (for function components) or `@Language.factory` (for class components).
#
# Available factories: attribute_ruler, tok2vec, merge_noun_chunks, merge_entities, merge_subtokens, token_splitter, parser, beam_parser, entity_linker, ner, beam_ner, entity_ruler, lemmatizer, tagger, morphologizer, senter, sentencizer, textcat, textcat_multilabel, en.lemmatizer
