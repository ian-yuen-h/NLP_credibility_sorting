# %%
import pandas as pd
import numpy as np
import json
# Opening JSON file
f = open('data.json',)
  
# returns JSON object as 
# a dictionary
data = json.load(f)

# Closing file
f.close()
# Out:
# [nltk_data] Error loading punkt: <urlopen error [Errno 61] Connection
# [nltk_data]     refused>

# %%
# %load_ext autoreload
# %autoreload 2
import pipeline_entity_quote as pipeline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
result_dict = {}

# %%
result_dict = pipeline.get_training_features_smalltrial()
# Out:
# Current Time = 22:40:29
# Current Time = 22:44:55

# %%
result_df = pd.DataFrame.from_dict(result_dict)
result_df
# Out:
#                     204f5d99-c9de-4bce-ae2f-5e98085b4930  \
# entity_num                                          54.0
# entity_type_num                                      9.0
# num_quote                                            0.0
# quote_subjectivity                                   NaN
# quote_polarity                                       NaN
#
#                     0526bd0d-41bb-43fe-bdc9-dabeea9dcfaa  \
# entity_num                                     22.000000
# entity_type_num                                 8.000000
# num_quote                                       8.000000
# quote_subjectivity                              0.128299
# quote_polarity                                  0.048438
#
#                     33e5aa3f-af33-461d-9e51-16a552e6b985  \
# entity_num                                     39.000000
# entity_type_num                                 7.000000
# num_quote                                      16.000000
# ...

# %%
result_dict_quote = {}
result_dict_quote = pipeline.get_training_features_quote_smalltrial()
# Out:
# Current Time = 17:35:57
# Current Time = 12:35:41

# %%
result_df_quote = pd.DataFrame.from_dict(result_dict_quote)
result_df_quote
# Out:
# [nltk_data] Error loading punkt: <urlopen error [Errno 61] Connection
# [nltk_data]     refused>
#                     204f5d99-c9de-4bce-ae2f-5e98085b4930  \
# num_quote                                            0.0
# quote_subjectivity                                   NaN
# quote_polarity                                       NaN
#
#                     0526bd0d-41bb-43fe-bdc9-dabeea9dcfaa  \
# num_quote                                       8.000000
# quote_subjectivity                              0.128299
# quote_polarity                                  0.048438
#
#                     33e5aa3f-af33-461d-9e51-16a552e6b985  \
# num_quote                                      16.000000
# quote_subjectivity                              0.399621
# quote_polarity                                 -0.031676
#
#                    d10f9f69-204a-422d-886d-ff59f787fe22  \
# num_quote                                          None
# quote_subjectivity                                 None
# ...

# %%
result_df_quote_t = result_df_quote.T
result_df_quote_t
# Out:
#                                      num_quote quote_subjectivity  \
# 204f5d99-c9de-4bce-ae2f-5e98085b4930       0.0                NaN
# 0526bd0d-41bb-43fe-bdc9-dabeea9dcfaa       8.0           0.128299
# 33e5aa3f-af33-461d-9e51-16a552e6b985      16.0           0.399621
# d10f9f69-204a-422d-886d-ff59f787fe22      None               None
# 88ffc85f-b495-4f59-af53-08a92030f9b7      None               None
# ...                                        ...                ...
# 8dd1f569-7c3f-43c4-9c26-1543d89e032c       1.0                0.0
# 7fca5388-231e-4206-a5b2-7d3cd765ba80       0.0                NaN
# f351f646-e3de-4b17-a457-c32741aafda0       0.0                NaN
# f2cb35b3-1f70-471e-8bae-207f157c6cdf       0.0                NaN
# f346bff6-b54e-4c4d-8f5d-44c740bd8e3a       0.0                NaN
#
#                                      quote_polarity
# 204f5d99-c9de-4bce-ae2f-5e98085b4930            NaN
# 0526bd0d-41bb-43fe-bdc9-dabeea9dcfaa       0.048438
# ...

# %%
result_df_quote_t.to_csv("quote_features.csv")
